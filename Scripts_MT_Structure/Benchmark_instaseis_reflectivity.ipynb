# %%
import instaseis

# %%
# db = instaseis.open_db("syngine://iasp91_2s")
# db = instaseis.open_db("http://instaseis.ethz.ch/marssynthetics/C30VH-BFT13-1s")
db = instaseis.open_db("/mnt/marshost/instaseis2/databases/Mars_local_10Hz_belowreg")

# %%
db
# Out:
# ReciprocalInstaseisDB reciprocal Green's function Database (v10) generated with these parameters:
# 	components           : vertical and horizontal
# 	velocity model       : external
# 	attenuation          : False
# 	dominant period      : 0.100 s
# 	dump type            : displ_only
# 	excitation type      : dipole
# 	time step            : 0.024 s
# 	sampling rate        : 41.011 Hz
# 	number of samples    : 4102
# 	seismogram length    : 100.0 s
# 	source time function : gauss_0
# 	source shift         : 0.171 s
# 	spatial order        : 4
# 	min/max radius       : 3380.0 - 3389.5 km
# 	Planet radius        : 3389.5 km
# 	min/max distance     : 0.0 - 180.0 deg
# 	time stepping scheme : symplec4
# 	compiler/user        : gfortran 5.3.0 20151204 (Cray Inc.) by UNKNOWN on UNKNOWN
# 	directory/url        : ../../../../../../mnt/marshost/instaseis2/databases/Mars_local_10Hz_belowreg
# 	size of netCDF files : 185.8 GB
# ...
